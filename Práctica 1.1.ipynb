# %%
import pandas as pd
import numpy as np
import missingno as msno
# %matplotlib inline

# %%
path = 'Cultivos_méxico_2018.csv'
df = pd.read_csv(path, encoding='utf-8', error_bad_lines=False)
df.head()
# Out:
#   Código Ámbito    Ámbito  Código área    Área  Código Elemento  \
# 0            QC  Cultivos          138  México             5312
# 1            QC  Cultivos          138  México             5312
# 2            QC  Cultivos          138  México             5312
# 3            QC  Cultivos          138  México             5312
# 4            QC  Cultivos          138  México             5312
#
#          Elemento  Código Producto               Producto  Código año   Año  \
# 0  Área cosechada              254  Aceite, nuez de palma        2018  2018
# 1  Área cosechada              260      Aceitunas, olivas        2018  2018
# 2  Área cosechada              800      Agave, fibras nep        2018  2018
# 3  Área cosechada              572              Aguacates        2018  2018
# 4  Área cosechada              406                    Ajo        2018  2018
#
#   Unidad     Valor Símbolo                            Descripción del Símbolo
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 112 entries, 0 to 111
# Data columns (total 14 columns):
# Código Ámbito              112 non-null object
# Ámbito                     112 non-null object
# Código área                112 non-null int64
# Área                       112 non-null object
# Código Elemento            112 non-null int64
# Elemento                   112 non-null object
# Código Producto            112 non-null int64
# Producto                   112 non-null object
# Código año                 112 non-null int64
# Año                        112 non-null int64
# Unidad                     112 non-null object
# Valor                      111 non-null float64
# Símbolo                    21 non-null object
# Descripción del Símbolo    112 non-null object
# dtypes: float64(1), int64(5), object(8)
# memory usage: 12.4+ KB

# %%
df.shape
# Out:
# (112, 14)

# %%
df.columns.values.tolist()
# Out:
# ['Código Ámbito',
#  'Ámbito',
#  'Código área',
#  'Área',
#  'Código Elemento',
#  'Elemento',
#  'Código Producto',
#  'Producto',
#  'Código año',
#  'Año',
#  'Unidad',
#  'Valor',
#  'Símbolo',
#  'Descripción del Símbolo']

# %%
df.dtypes
# Out:
# Código Ámbito               object
# Ámbito                      object
# Código área                  int64
# Área                        object
# Código Elemento              int64
# Elemento                    object
# Código Producto              int64
# Producto                    object
# Código año                   int64
# Año                          int64
# Unidad                      object
# Valor                      float64
# Símbolo                     object
# Descripción del Símbolo     object
# dtype: object

# %%
df.isnull().any().any()
# Out:
# True

# %%
msno.matrix(df)

# %%
df.replace({' ': np.nan}, inplace=True)

# %%
df.isnull().any().any()
# Out:
# True

# %%
msno.matrix(df)

# %%
msno.bar(df)

# %%
df.columns[df.isnull().any()].tolist()
# Out:
# ['Valor', 'Símbolo']

# %%
df.describe()
# Out:
#        Código área  Código Elemento  Código Producto  Código año     Año  \
# count        112.0            112.0       112.000000       112.0   112.0
# mean         138.0           5312.0       394.008929      2018.0  2018.0
# std            0.0              0.0       204.706888         0.0     0.0
# min          138.0           5312.0        15.000000      2018.0  2018.0
# 25%          138.0           5312.0       222.750000      2018.0  2018.0
# 50%          138.0           5312.0       401.500000      2018.0  2018.0
# 75%          138.0           5312.0       548.250000      2018.0  2018.0
# max          138.0           5312.0       836.000000      2018.0  2018.0
#
#               Valor
# count  1.110000e+02
# mean   1.452077e+05
# std    7.043952e+05
# min    1.000000e+00
# 25%    2.165000e+03
# 50%    1.250600e+04
# 75%    5.221750e+04
# max    7.122710e+06

# %%
df.loc[[0]]
# Out:
#   Código Ámbito    Ámbito  Código área    Área  Código Elemento  \
# 0            QC  Cultivos          138  México             5312
#
#          Elemento  Código Producto               Producto  Código año   Año  \
# 0  Área cosechada              254  Aceite, nuez de palma        2018  2018
#
#   Unidad    Valor Símbolo Descripción del Símbolo
# 0     ha  72841.0     NaN         Datos oficiales

# %%
df.loc[30:33]
# Out:
#    Código Ámbito    Ámbito  Código área    Área  Código Elemento  \
# 30            QC  Cultivos          138  México             5312
# 31            QC  Cultivos          138  México             5312
# 32            QC  Cultivos          138  México             5312
# 33            QC  Cultivos          138  México             5312
#
#           Elemento  Código Producto                   Producto  Código año  \
# 30  Área cosechada               71                    Centeno        2018
# 31  Área cosechada              108               Cereales nep        2018
# 32  Área cosechada              531                    Cerezas        2018
# 33  Área cosechada              689  Chiles y pimientos, secos        2018
#
#      Año Unidad    Valor Símbolo  \
# 30  2018     ha      5.0     NaN
# 31  2018     ha   3552.0     NaN
# 32  2018     ha     48.0     NaN
# 33  2018     ha  31590.0      Im
#
#                               Descripción del Símbolo
# ...

# %%
df.drop([0,24,51], axis=0).head()
# Out:
#   Código Ámbito    Ámbito  Código área    Área  Código Elemento  \
# 1            QC  Cultivos          138  México             5312
# 2            QC  Cultivos          138  México             5312
# 3            QC  Cultivos          138  México             5312
# 4            QC  Cultivos          138  México             5312
# 5            QC  Cultivos          138  México             5312
#
#          Elemento  Código Producto           Producto  Código año   Año  \
# 1  Área cosechada              260  Aceitunas, olivas        2018  2018
# 2  Área cosechada              800  Agave, fibras nep        2018  2018
# 3  Área cosechada              572          Aguacates        2018  2018
# 4  Área cosechada              406                Ajo        2018  2018
# 5  Área cosechada              526       Albaricoques        2018  2018
#
#   Unidad     Valor Símbolo                            Descripción del Símbolo
# ...

# %%
df.drop(df.index[1:5], axis=0).head(10)
# Out:
#    Código Ámbito    Ámbito  Código área    Área  Código Elemento  \
# 0             QC  Cultivos          138  México             5312
# 5             QC  Cultivos          138  México             5312
# 6             QC  Cultivos          138  México             5312
# 7             QC  Cultivos          138  México             5312
# 8             QC  Cultivos          138  México             5312
# 9             QC  Cultivos          138  México             5312
# 10            QC  Cultivos          138  México             5312
# 11            QC  Cultivos          138  México             5312
# 12            QC  Cultivos          138  México             5312
# 13            QC  Cultivos          138  México             5312
#
#           Elemento  Código Producto                        Producto  \
# 0   Área cosechada              254           Aceite, nuez de palma
# 5   Área cosechada              526                    Albaricoques
# ...

# %%
df[100:].head() #df.tail(-100) )
# Out:
#     Código Ámbito    Ámbito  Código área    Área  Código Elemento  \
# 100            QC  Cultivos          138  México             5312
# 101            QC  Cultivos          138  México             5312
# 102            QC  Cultivos          138  México             5312
# 103            QC  Cultivos          138  México             5312
# 104            QC  Cultivos          138  México             5312
#
#            Elemento  Código Producto  \
# 100  Área cosechada              826
# 101  Área cosechada              495
# 102  Área cosechada              388
# 103  Área cosechada              507
# 104  Área cosechada               15
#
#                                           Producto  Código año   Año Unidad  \
# 100                                   Tabaco bruto        2018  2018     ha
# 101  Tangerinas, mandarinas, clementinas, satsumas        2018  2018     ha
# 102                               Tomates, frescos        2018  2018     ha
# ...

# %%
df.Producto.values
# Out:
# array(['Aceite, nuez de palma', 'Aceitunas, olivas', 'Agave, fibras nep',
#        'Aguacates', 'Ajo', 'Albaricoques', 'Alcachofas', 'Algarrobas',
#        'Algodón con semilla', 'Almendras con cáscara', 'Alpiste',
#        'Anacardos, con cáscara', 'Anís, badián, hinojo, cilantro',
#        'Arándanos', 'Arroz, cascara', 'Avena', 'Azucar, caña',
#        'Azucar, remolacha', 'Bananos', 'Batatas, boniatos', 'Bayas nep',
#        'Berenjenas', 'Cacao, en grano', 'Café, verde',
#        'Calabazas, zapayo, calabaza confitera', 'Caquis',
#        'Caucho natural', 'Cebada', 'Cebollas, chalotes, verdes',
#        'Cebollas, secas', 'Centeno', 'Cereales nep', 'Cerezas',
#        'Chiles y pimientos, secos',
#        'Chiles, pimientos picantes, pimientos (verdes)',
#        'Ciruelas y endrinas', 'Clavo de olor', 'Coles y otras crucíferas',
#        'Coliflor y brécol', 'Colza', 'Dátiles', 'Esparragos',
#        'Especias nep', 'Espinacas', 'Frambuesas', 'Fresas',
# ...

# %%
df['Producto'].values
# Out:
# array(['Aceite, nuez de palma', 'Aceitunas, olivas', 'Agave, fibras nep',
#        'Aguacates', 'Ajo', 'Albaricoques', 'Alcachofas', 'Algarrobas',
#        'Algodón con semilla', 'Almendras con cáscara', 'Alpiste',
#        'Anacardos, con cáscara', 'Anís, badián, hinojo, cilantro',
#        'Arándanos', 'Arroz, cascara', 'Avena', 'Azucar, caña',
#        'Azucar, remolacha', 'Bananos', 'Batatas, boniatos', 'Bayas nep',
#        'Berenjenas', 'Cacao, en grano', 'Café, verde',
#        'Calabazas, zapayo, calabaza confitera', 'Caquis',
#        'Caucho natural', 'Cebada', 'Cebollas, chalotes, verdes',
#        'Cebollas, secas', 'Centeno', 'Cereales nep', 'Cerezas',
#        'Chiles y pimientos, secos',
#        'Chiles, pimientos picantes, pimientos (verdes)',
#        'Ciruelas y endrinas', 'Clavo de olor', 'Coles y otras crucíferas',
#        'Coliflor y brécol', 'Colza', 'Dátiles', 'Esparragos',
#        'Especias nep', 'Espinacas', 'Frambuesas', 'Fresas',
# ...

# %%
df.Producto.unique()
# Out:
# array(['Aceite, nuez de palma', 'Aceitunas, olivas', 'Agave, fibras nep',
#        'Aguacates', 'Ajo', 'Albaricoques', 'Alcachofas', 'Algarrobas',
#        'Algodón con semilla', 'Almendras con cáscara', 'Alpiste',
#        'Anacardos, con cáscara', 'Anís, badián, hinojo, cilantro',
#        'Arándanos', 'Arroz, cascara', 'Avena', 'Azucar, caña',
#        'Azucar, remolacha', 'Bananos', 'Batatas, boniatos', 'Bayas nep',
#        'Berenjenas', 'Cacao, en grano', 'Café, verde',
#        'Calabazas, zapayo, calabaza confitera', 'Caquis',
#        'Caucho natural', 'Cebada', 'Cebollas, chalotes, verdes',
#        'Cebollas, secas', 'Centeno', 'Cereales nep', 'Cerezas',
#        'Chiles y pimientos, secos',
#        'Chiles, pimientos picantes, pimientos (verdes)',
#        'Ciruelas y endrinas', 'Clavo de olor', 'Coles y otras crucíferas',
#        'Coliflor y brécol', 'Colza', 'Dátiles', 'Esparragos',
#        'Especias nep', 'Espinacas', 'Frambuesas', 'Fresas',
# ...

# %%
df.Producto.value_counts()
# Out:
# Anacardos, con cáscara       1
# Semilla de melón             1
# Azucar, remolacha            1
# Chiles y pimientos, secos    1
# Frijoles, secos              1
#                             ..
# Colza                        1
# Judías verdes con hilo       1
# Maiz                         1
# Semillas de jojoba           1
# Mijo                         1
# Name: Producto, Length: 112, dtype: int64

# %%
df.agg(['count', 'size', 'nunique'])
# Out:
#          Código Ámbito  Ámbito  Código área  Área  Código Elemento  Elemento  \
# count              112     112          112   112              112       112
# size               112     112          112   112              112       112
# nunique              1       1            1     1                1         1
#
#          Código Producto  Producto  Código año  Año  Unidad  Valor  Símbolo  \
# count                112       112         112  112     112    111       21
# size                 112       112         112  112     112    112      112
# nunique              112       112           1    1       1    111        3
#
#          Descripción del Símbolo
# count                        112
# size                         112
# nunique                        4

# %%
df.groupby('Producto').agg(['count', 'size', 'nunique']).stack()
# Out:
#                                Código Ámbito  Ámbito  Código área  Área  \
# Producto
# Aceite, nuez de palma count                1       1            1     1
#                       size                 1       1            1     1
#                       nunique              1       1            1     1
# Aceitunas, olivas     count                1       1            1     1
#                       size                 1       1            1     1
# ...                                      ...     ...          ...   ...
# Yuca                  size                 1       1            1     1
#                       nunique              1       1            1     1
# Zanahorias y nabos    count                1       1            1     1
#                       size                 1       1            1     1
#                       nunique              1       1            1     1
#
#                                Código Elemento  Elemento  Código Producto  \
# Producto
# ...

# %%
df.groupby('Producto').agg(['count', 'size', 'nunique'])
# Out:
#                       Código Ámbito              Ámbito               \
#                               count size nunique  count size nunique
# Producto
# Aceite, nuez de palma             1    1       1      1    1       1
# Aceitunas, olivas                 1    1       1      1    1       1
# Agave, fibras nep                 1    1       1      1    1       1
# Aguacates                         1    1       1      1    1       1
# Ajo                               1    1       1      1    1       1
# ...                             ...  ...     ...    ...  ...     ...
# Vainilla                          1    1       1      1    1       1
# Veza                              1    1       1      1    1       1
# Yautia (cocoyam)                  1    1       1      1    1       1
# Yuca                              1    1       1      1    1       1
# Zanahorias y nabos                1    1       1      1    1       1
#
# ...

# %%
df_sample = df.sample(frac=0.05, random_state=1)
df_sample.head()
# Out:
#    Código Ámbito    Ámbito  Código área    Área  Código Elemento  \
# 91            QC  Cultivos          138  México             5312
# 44            QC  Cultivos          138  México             5312
# 56            QC  Cultivos          138  México             5312
# 82            QC  Cultivos          138  México             5312
# 69            QC  Cultivos          138  México             5312
#
#           Elemento  Código Producto                       Producto  \
# 91  Área cosechada              280     Semilla de cartamo, alazor
# 44  Área cosechada              547                     Frambuesas
# 56  Área cosechada              420     Hortalizas leguminosas nep
# 82  Área cosechada              397            Pepinos, pepinillos
# 69  Área cosechada              242  Manís (cacahuete) con cáscara
#
#     Código año   Año Unidad    Valor Símbolo Descripción del Símbolo
# 91        2018  2018     ha  26709.0     NaN         Datos oficiales
# ...

# %%
df.shape
# Out:
# (112, 14)

# %%
df_sample.shape
# Out:
# (6, 14)

# %%
df_dropped = df.dropna(subset=['Valor'])
df_dropped.head()
# Out:
#   Código Ámbito    Ámbito  Código área    Área  Código Elemento  \
# 0            QC  Cultivos          138  México             5312
# 1            QC  Cultivos          138  México             5312
# 2            QC  Cultivos          138  México             5312
# 3            QC  Cultivos          138  México             5312
# 4            QC  Cultivos          138  México             5312
#
#          Elemento  Código Producto               Producto  Código año   Año  \
# 0  Área cosechada              254  Aceite, nuez de palma        2018  2018
# 1  Área cosechada              260      Aceitunas, olivas        2018  2018
# 2  Área cosechada              800      Agave, fibras nep        2018  2018
# 3  Área cosechada              572              Aguacates        2018  2018
# 4  Área cosechada              406                    Ajo        2018  2018
#
#   Unidad     Valor Símbolo                            Descripción del Símbolo
# ...

# %%
df_dropped.shape
# Out:
# (111, 14)

# %%
df_copy = df.copy()
df_copy.head()
# Out:
#   Código Ámbito    Ámbito  Código área    Área  Código Elemento  \
# 0            QC  Cultivos          138  México             5312
# 1            QC  Cultivos          138  México             5312
# 2            QC  Cultivos          138  México             5312
# 3            QC  Cultivos          138  México             5312
# 4            QC  Cultivos          138  México             5312
#
#          Elemento  Código Producto               Producto  Código año   Año  \
# 0  Área cosechada              254  Aceite, nuez de palma        2018  2018
# 1  Área cosechada              260      Aceitunas, olivas        2018  2018
# 2  Área cosechada              800      Agave, fibras nep        2018  2018
# 3  Área cosechada              572              Aguacates        2018  2018
# 4  Área cosechada              406                    Ajo        2018  2018
#
#   Unidad     Valor Símbolo                            Descripción del Símbolo
# ...

# %%
df_copy.shape
# Out:
# (112, 14)

# %%
df_dropped['Código Producto'].dtype
# Out:
# dtype('int64')

# %%
df_dropped['Código Producto'].mean()
# Out:
# 391.27027027027026

# %%
df_copy['Valor'].fillna(value=np.round(df['Valor'].mean(),decimals=0), inplace=True)

# %%
df_copy.agg(['count', 'size', 'nunique'])
# Out:
#          Código Ámbito  Ámbito  Código área  Área  Código Elemento  Elemento  \
# count              112     112          112   112              112       112
# size               112     112          112   112              112       112
# nunique              1       1            1     1                1         1
#
#          Código Producto  Producto  Código año  Año  Unidad  Valor  Símbolo  \
# count                112       112         112  112     112    112       21
# size                 112       112         112  112     112    112      112
# nunique              112       112           1    1       1    112        3
#
#          Descripción del Símbolo
# count                        112
# size                         112
# nunique                        4

# %%
list(df['Valor'].unique())
# Out:
# [72841.0,
#  5200.0,
#  13712.0,
#  206389.0,
#  7348.0,
#  175.0,
#  218.0,
#  76.0,
#  240580.0,
#  31.0,
#  1.0,
#  1419.0,
#  7712.0,
#  3611.0,
#  45150.0,
#  49911.0,
#  785905.0,
#  47.0,
#  78533.0,
#  3334.0,
#  13164.0,
#  2330.0,
#  58361.0,
#  629799.0,
#  38177.0,
#  4.0,
#  25418.0,
#  352113.0,
#  7329.0,
#  50168.0,
#  5.0,
#  3552.0,
#  48.0,
#  31590.0,
#  156799.0,
#  14753.0,
#  nan,
#  6181.0,
#  39849.0,
#  5000.0,
#  1573.0,
#  30792.0,
#  578.0,
#  2436.0,
#  7151.0,
#  13652.0,
#  1596224.0,
#  39888.0,
#  77092.0,
#  48054.0,
#  194370.0,
#  3443.0,
#  1436.0,
#  11684.0,
#  21166.0,
#  1194.0,
#  11807.0,
#  105862.0,
#  391.0,
#  12506.0,
#  8897.0,
#  20527.0,
#  389.0,
#  8080.0,
#  175826.0,
#  3000.0,
#  7122710.0,
#  67625.0,
#  210685.0,
#  52046.0,
#  52389.0,
#  25562.0,
#  18959.0,
#  598.0,
#  68.0,
#  14.0,
#  326689.0,
#  96909.0,
#  63301.0,
#  185708.0,
#  60303.0,
#  17923.0,
#  19597.0,
#  4089.0,
#  3186.0,
#  20771.0,
#  109.0,
#  642.0,
# ...

# %%
list(df['Producto'].unique())
# Out:
# ['Aceite, nuez de palma',
#  'Aceitunas, olivas',
#  'Agave, fibras nep',
#  'Aguacates',
#  'Ajo',
#  'Albaricoques',
#  'Alcachofas',
#  'Algarrobas',
#  'Algodón con semilla',
#  'Almendras con cáscara',
#  'Alpiste',
#  'Anacardos, con cáscara',
#  'Anís, badián, hinojo, cilantro',
#  'Arándanos',
#  'Arroz, cascara',
#  'Avena',
#  'Azucar, caña',
#  'Azucar, remolacha',
#  'Bananos',
#  'Batatas, boniatos',
#  'Bayas nep',
#  'Berenjenas',
#  'Cacao, en grano',
#  'Café, verde',
#  'Calabazas, zapayo, calabaza confitera',
#  'Caquis',
#  'Caucho natural',
#  'Cebada',
#  'Cebollas, chalotes, verdes',
#  'Cebollas, secas',
#  'Centeno',
#  'Cereales nep',
#  'Cerezas',
#  'Chiles y pimientos, secos',
#  'Chiles, pimientos picantes, pimientos (verdes)',
#  'Ciruelas y endrinas',
#  'Clavo de olor',
#  'Coles y otras crucíferas',
#  'Coliflor y brécol',
#  'Colza',
#  'Dátiles',
#  'Esparragos',
#  'Especias nep',
#  'Espinacas',
#  'Frambuesas',
#  'Fresas',
# ...

# %%
keys = list(df['Producto'].unique())
vals = range(1,8)
act = dict(zip(keys, vals))
act
# Out:
# {'Aceite, nuez de palma': 1,
#  'Aceitunas, olivas': 2,
#  'Agave, fibras nep': 3,
#  'Aguacates': 4,
#  'Ajo': 5,
#  'Albaricoques': 6,
#  'Alcachofas': 7}

# %%
df_copy['Valor'].mean()
# Out:
# 145207.66964285713

# %%
df_copy['Producto'][df_copy['Valor'] != 6]
# Out:
# 0      Aceite, nuez de palma
# 1          Aceitunas, olivas
# 2          Agave, fibras nep
# 3                  Aguacates
# 4                        Ajo
#                ...
# 107                 Vainilla
# 108                     Veza
# 109         Yautia (cocoyam)
# 110                     Yuca
# 111       Zanahorias y nabos
# Name: Producto, Length: 112, dtype: object

# %%
df_copy['Valor'][df_copy['Producto'] != 6].mean()
# Out:
# 145207.66964285713

# %%
import matplotlib.pyplot as plt
plt.style.use('seaborn-white')

ax1 = plt.axes()  # standard axes
ax2 = plt.axes([0.65, 0.65, 0.2, 0.2])

# %%
#The equivalent of this command within the object-oriented interface is fig.add_axes()

fig = plt.figure()
ax1 = fig.add_axes([0.1, 0.5, 0.8, 0.4],
                   xticklabels=[], ylim=(-1.2, 1.2))
ax2 = fig.add_axes([0.1, 0.1, 0.8, 0.4],
                   ylim=(-1.2, 1.2))

x = np.linspace(0, 10)
ax1.plot(np.sin(x))
ax2.plot(np.cos(x))

# %%
# The lowest level of these is plt.subplot(), which creates a single subplot within a grid
for i in range(1, 7):
    plt.subplot(2, 3, i)
    plt.text(0.5, 0.5, str((2, 3, i)),
             fontsize=18, ha='center')

# %%
# plt.subplots_adjust can be used to adjust the spacing between these plots
fig = plt.figure()
fig.subplots_adjust(hspace=0.4, wspace=0.4)
for i in range(1, 7):
    ax = fig.add_subplot(2, 3, i)
    ax.text(0.5, 0.5, str((2, 3, i)),
           fontsize=18, ha='center')

# %%
fig, ax = plt.subplots(2, 3, sharex='col', sharey='row')

# %%
# axes are in a two-dimensional array, indexed by [row, col]
for i in range(2):
    for j in range(3):
        ax[i, j].text(0.5, 0.5, str((i, j)),
                      fontsize=18, ha='center')
fig

# %%
# Create some normally distributed data
mean = [0, 0]
cov = [[1, 1], [1, 2]]
x, y = np.random.multivariate_normal(mean, cov, 3000).T

# Set up the axes with gridspec
fig = plt.figure(figsize=(6, 6))
grid = plt.GridSpec(4, 4, hspace=0.2, wspace=0.2)
main_ax = fig.add_subplot(grid[:-1, 1:])
y_hist = fig.add_subplot(grid[:-1, 0], xticklabels=[], sharey=main_ax)
x_hist = fig.add_subplot(grid[-1, 1:], yticklabels=[], sharex=main_ax)

# scatter points on the main axes
main_ax.plot(x, y, 'ok', markersize=3, alpha=0.2)

# histogram on the attached axes
x_hist.hist(x, 40, histtype='stepfilled',
            orientation='vertical', color='gray')
x_hist.invert_yaxis()

y_hist.hist(y, 40, histtype='stepfilled',
            orientation='horizontal', color='gray')
y_hist.invert_xaxis()

# %%
#figure.savefig('.../.jpeg')
#df_sample['ventas'] = dropna()
df_sample['Valor'] = df_sample['Valor'].astype('int64')

df_sample.plot(kind='scatter',x='Valor',y='Código Producto')

# %%
plt.hist(df_sample['Producto'])
plt.xlabel('Producto')
plt.ylabel('Frequency')
plt.title('Frequency of tipoact')
# Out:
# Text(0.5, 1.0, 'Frequency of tipoact')

# %%
#plt.boxplot(df_sample['ventas'])
plt.boxplot(df_sample['Valor'], showmeans=True, meanline=True)
plt.ylabel('ventas count')
plt.title('Box Plot of ventas count')
# Out:
# Text(0.5, 1.0, 'Box Plot of ventas count')
